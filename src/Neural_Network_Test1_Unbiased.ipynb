# %%
#First we need to import the pandas library
import pandas as pd

#Load our lung cancer dataset into object ds
ds = pd.read_csv('/Users/haydenwhite/Documents/USC Upstate/599 Senior Seminar/src/survey_lung_cancer.csv')

#Lets first print the number of rows and columns of the dataset
print('Size of dataset', ds.shape)
#Lets verify our filepath is correct by previewing the data with the following head() method call
ds.head()

#If we had any cells with N/A, we can remove those rows with: ds = ds.dropna()
# Out:
# Size of dataset (309, 16)
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO

# %%
#****NOW LETS HANDLE THE BIASED DATA BY REMOVING SOME "YES"'S IN THE LUNG CANCER COLUMN*****

numNo = 0
numYes = 0
for index, row in ds.iterrows():
    if row[15] == 'NO':
            numNo += 1
    else:
        numYes += 1
print('No:', numNo)
print('Yes:', numYes)

for index, row in ds.iterrows():
    #print(row) #Debug
    if row[15] == 'YES' and numYes > numNo:
        ds = ds.drop(index, axis=0)
        numYes -= 1
print('No:', numNo)
print('Yes:', numYes)
ds.head()
# Out:
# No: 39
# Yes: 270
# No: 39
# Yes: 39
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2       F   59        1               1        1              2
# 3       M   63        2               2        2              1
# 4       F   63        1               2        1              1
# 8       F   68        2               1        2              1
# 12      F   60        2               1        1              1
#
#     CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 2                 1         2         1         2                  1
# 3                 1         1         1         1                  2
# 4                 1         1         1         2                  1
# 8                 1         2         1         1                  1
# 12                1         2         1         1                  1
#
#     COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 2          2                    2                      1           2
# 3          1                    1                      2           2
# 4          2                    2                      1           1
# 8          1                    1                      1           1
# 12         1                    2                      1           1
#
#    LUNG_CANCER
# 2           NO
# 3           NO
# 4           NO
# 8           NO
# 12          NO

# %%
#Now we need to make some adjustments to the data
#Lets start by replacing all the '1s' with 0 and all the '2s' with 1
#Note: 'FATIGUE ' and 'ALLERGY ' have an extra whitespace at the end of their string
ds['SMOKING'].replace({1: 0, 2: 1}, inplace = True)
ds['YELLOW_FINGERS'].replace({1: 0, 2: 1}, inplace = True)
ds['SMOKING'].replace({1: 0, 2: 1}, inplace = True)
ds['ANXIETY'].replace({1: 0, 2: 1}, inplace = True)
ds['PEER_PRESSURE'].replace({1: 0, 2: 1}, inplace = True)
ds['CHRONIC DISEASE'].replace({1: 0, 2: 1}, inplace = True)
ds['FATIGUE '].replace({1: 0, 2: 1}, inplace = True)
ds['ALLERGY '].replace({1: 0, 2: 1}, inplace = True)
ds['WHEEZING'].replace({1: 0, 2: 1}, inplace = True)
ds['ALCOHOL CONSUMING'].replace({1: 0, 2: 1}, inplace = True)
ds['COUGHING'].replace({1: 0, 2: 1}, inplace = True)
ds['SHORTNESS OF BREATH'].replace({1: 0, 2: 1}, inplace = True)
ds['SWALLOWING DIFFICULTY'].replace({1: 0, 2: 1}, inplace = True)
ds['CHEST PAIN'].replace({1: 0, 2: 1}, inplace = True)

#Now lets replace the 'YES' and 'NO' values in the 'LUNG_CANCER' column with '1' and '0' respectively
ds['LUNG_CANCER'].replace({'NO': 0, 'YES': 1}, inplace = True)

#For debugging purposes, lets replace 'M' with 1 and 'F' with 0 for the GENDER column
ds['GENDER'].replace({'F': 0, 'M': 1}, inplace = True)

ds.head()
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2        0   59        0               0        0              1
# 3        1   63        0               1        1              0
# 4        0   63        0               1        0              0
# 8        0   68        0               0        1              0
# 12       0   60        0               0        0              0
#
#     CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 2                 0         1         0         1                  0
# 3                 0         0         0         0                  1
# 4                 0         0         0         1                  0
# 8                 0         1         0         0                  0
# 12                0         1         0         0                  0
#
#     COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 2          1                    1                      0           1
# 3          0                    0                      1           1
# 4          1                    1                      0           0
# 8          0                    0                      0           0
# 12         0                    1                      0           0
#
#     LUNG_CANCER
# 2             0
# 3             0
# 4             0
# 8             0
# 12            0

# %%
#Now lets convert our dataset into an array that the machine can process
dataset = ds.values

#We can view this dataset by simply writing "dataset"
dataset
# Out:
# array([[ 0, 59,  0, ...,  0,  1,  0],
#        [ 1, 63,  0, ...,  1,  1,  0],
#        [ 0, 63,  0, ...,  0,  0,  0],
#        ...,
#        [ 1, 58,  0, ...,  0,  1,  1],
#        [ 1, 67,  0, ...,  0,  1,  1],
#        [ 1, 62,  0, ...,  1,  0,  1]])

# %%
#Now we need to split our dataset so that the input features (first 15 columns) are stored in X and 
#the output feature (column 16) is stored in Y
X = dataset[:,0:15] #Storing columns 1-15 in X
Y = dataset[:,15]   #Storing column 16 in Y

#Luckily, the vast majority  of our data is binary (either a 0 or 1) EXCEPT for the Age column
#We need to scale the age column so that it lies between 0 or 1 inclusive
#We do this by importing the processing module from sklearn
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler() #Creating the preprocessing object
X_scale = min_max_scaler.fit_transform(X)     #Scaling the input X as new variable X_scale

#Lets take a peak at how this changed the Age column
X_scale
# Out:
# array([[0.        , 0.57575758, 0.        , ..., 1.        , 0.        ,
#         1.        ],
#        [1.        , 0.63636364, 0.        , ..., 0.        , 1.        ,
#         1.        ],
#        [0.        , 0.63636364, 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [1.        , 0.56060606, 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [1.        , 0.6969697 , 0.        , ..., 1.        , 0.        ,
#         1.        ],
#        [1.        , 0.62121212, 0.        , ..., 0.        , 1.        ,
#         0.        ]])

# %%
#Now we need to split our dataset into a training set, a test set, and a validation set
#We will do so by importing test_train_spolit from sklearn.model_selection
from sklearn.model_selection import train_test_split

#We group the validation and test data into one X and Y set, and our 
#training data into another X and Y set
#test_size=0.3 means we are splitting our data such that 70% is training and 30% is test/validate
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

#Since Test data and Validation data are grouped together we can call the same function
#To split those into their own individual sets
#We will split them equally using test_size=0.5
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

#We can view the shape of all 6 arrays by printing them
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (54, 15) (12, 15) (12, 15) (54,) (12,) (12,)

# %%
#Now our data is ready to train a neural network

#Setting up the neural network, we need to decide how many hidden layers we want
#as well as how many neurons should belong to each layer

#The situations in which performance improves with a second (or third, etc.) 
#hidden layer are very few. One hidden layer is sufficient for the large majority of problems.

#So what about the size of the hidden layer(s)--how many neurons? There are some empirically derived 
#rules of thumb; of these, the most commonly relied on is 'the optimal size of the hidden layer is 
#usually between the size of the input and size of the output layers'. 

#In sum, for most problems, one could probably get decent performance (even without a second optimization step) 
#by setting the hidden layer configuration using just two rules: (i) the number of hidden layers equals one; 
#and (ii) the number of neurons in that layer is the mean of the neurons in the input and output layers. 

#With this guidence in mind, we will begin with a neural network containing one hidden layer with the amount
#of neurons equaling the mean of the input+output neurons (16) divided by 2 (16/2 = 8 layers).

#Later on we can experiment with additional hidden layers and/or neurons

#Lets import the necessary modules
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras import regularizers #Let's just test out this code for a second and see if it improves the model

#Now lets specify the architecture of the model
model = Sequential([
    Dense(16, activation='relu', input_shape=(15,)),  #Describes hidden layer and specifies number of input neurons
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid'),                  #Describes the output layer
])

#Now lets configure our model with the following attributes
#1) The algorithm for our optimization
#2) The loss function we want to use
#3) Metrics we want to track apart from the loss function

model.compile(optimizer='sgd',             #sgd refers to Stochastic Gradient Descent
              loss='binary_crossentropy',  #This means our loss function is for outputs of 0 or 1
              metrics=['accuracy'])        #We want to keep track of model accuracy for comparison

#Now we are ready to train our model
#Here we are fitting our parameters to the data
#This function outputs a history, which we store as 'hist'
hist = model.fit(X_train, Y_train,         #Specifying our training data is in X_train and Y_train
          batch_size=4, epochs=100,       #batch_size=32 and epochs=100 is a standard for NN
          validation_data=(X_val, Y_val))  #Tells us how we are doing on the validation data at each point
# Out:
# Epoch 1/100
# 2022-09-30 15:52:24.501948: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6630 - accuracy: 0.6111 - val_loss: 0.7115 - val_accuracy: 0.3333
# Epoch 2/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6586 - accuracy: 0.6296 - val_loss: 0.7122 - val_accuracy: 0.3333
# Epoch 3/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6537 - accuracy: 0.6296 - val_loss: 0.7108 - val_accuracy: 0.3333
# Epoch 4/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6487 - accuracy: 0.6296 - val_loss: 0.7108 - val_accuracy: 0.3333
# Epoch 5/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6432 - accuracy: 0.6111 - val_loss: 0.7076 - val_accuracy: 0.3333
# Epoch 6/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6390 - accuracy: 0.6296 - val_loss: 0.7002 - val_accuracy: 0.3333
# Epoch 7/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6348 - accuracy: 0.6296 - val_loss: 0.6990 - val_accuracy: 0.3333
# Epoch 8/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6290 - accuracy: 0.6111 - val_loss: 0.6974 - val_accuracy: 0.3333
# Epoch 9/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6243 - accuracy: 0.6111 - val_loss: 0.6918 - val_accuracy: 0.3333
# Epoch 10/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6192 - accuracy: 0.6111 - val_loss: 0.6893 - val_accuracy: 0.3333
# Epoch 11/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6149 - accuracy: 0.6111 - val_loss: 0.6874 - val_accuracy: 0.3333
# Epoch 12/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6092 - accuracy: 0.6111 - val_loss: 0.6812 - val_accuracy: 0.3333
# Epoch 13/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6034 - accuracy: 0.6111 - val_loss: 0.6751 - val_accuracy: 0.3333
# Epoch 14/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5985 - accuracy: 0.6667 - val_loss: 0.6722 - val_accuracy: 0.3333
# Epoch 15/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5925 - accuracy: 0.7037 - val_loss: 0.6648 - val_accuracy: 0.3333
# Epoch 16/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5876 - accuracy: 0.7222 - val_loss: 0.6582 - val_accuracy: 0.3333
# Epoch 17/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5814 - accuracy: 0.7222 - val_loss: 0.6512 - val_accuracy: 0.5000
# Epoch 18/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5770 - accuracy: 0.7222 - val_loss: 0.6400 - val_accuracy: 0.7500
# Epoch 19/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5711 - accuracy: 0.7407 - val_loss: 0.6327 - val_accuracy: 0.7500
# Epoch 20/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5647 - accuracy: 0.7407 - val_loss: 0.6308 - val_accuracy: 0.7500
# Epoch 21/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5578 - accuracy: 0.7407 - val_loss: 0.6166 - val_accuracy: 0.7500
# Epoch 22/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5516 - accuracy: 0.7407 - val_loss: 0.6138 - val_accuracy: 0.7500
# Epoch 23/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5464 - accuracy: 0.7407 - val_loss: 0.6009 - val_accuracy: 0.7500
# Epoch 24/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5382 - accuracy: 0.7407 - val_loss: 0.5911 - val_accuracy: 0.7500
# Epoch 25/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5335 - accuracy: 0.7963 - val_loss: 0.5883 - val_accuracy: 0.7500
# Epoch 26/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5260 - accuracy: 0.7778 - val_loss: 0.5802 - val_accuracy: 0.7500
# Epoch 27/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5183 - accuracy: 0.7593 - val_loss: 0.5680 - val_accuracy: 0.7500
# Epoch 28/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5111 - accuracy: 0.7963 - val_loss: 0.5562 - val_accuracy: 0.7500
# Epoch 29/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5036 - accuracy: 0.8333 - val_loss: 0.5462 - val_accuracy: 0.7500
# Epoch 30/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4964 - accuracy: 0.8148 - val_loss: 0.5338 - val_accuracy: 0.8333
# Epoch 31/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4889 - accuracy: 0.8519 - val_loss: 0.5235 - val_accuracy: 0.8333
# Epoch 32/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4818 - accuracy: 0.8519 - val_loss: 0.5161 - val_accuracy: 0.8333
# Epoch 33/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4742 - accuracy: 0.8519 - val_loss: 0.5068 - val_accuracy: 0.8333
# Epoch 34/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4667 - accuracy: 0.8519 - val_loss: 0.4997 - val_accuracy: 0.8333
# Epoch 35/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4594 - accuracy: 0.8519 - val_loss: 0.4930 - val_accuracy: 0.8333
# Epoch 36/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4522 - accuracy: 0.8519 - val_loss: 0.4847 - val_accuracy: 0.8333
# Epoch 37/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4452 - accuracy: 0.8519 - val_loss: 0.4726 - val_accuracy: 0.8333
# Epoch 38/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4392 - accuracy: 0.8519 - val_loss: 0.4595 - val_accuracy: 0.8333
# Epoch 39/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4336 - accuracy: 0.8704 - val_loss: 0.4485 - val_accuracy: 0.8333
# Epoch 40/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4252 - accuracy: 0.8519 - val_loss: 0.4342 - val_accuracy: 0.8333
# Epoch 41/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4174 - accuracy: 0.8704 - val_loss: 0.4251 - val_accuracy: 0.8333
# Epoch 42/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4118 - accuracy: 0.8704 - val_loss: 0.4093 - val_accuracy: 0.9167
# Epoch 43/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4060 - accuracy: 0.8704 - val_loss: 0.4119 - val_accuracy: 0.8333
# Epoch 44/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3972 - accuracy: 0.8704 - val_loss: 0.4064 - val_accuracy: 0.8333
# Epoch 45/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3908 - accuracy: 0.8704 - val_loss: 0.4012 - val_accuracy: 0.8333
# Epoch 46/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3857 - accuracy: 0.8704 - val_loss: 0.3966 - val_accuracy: 0.8333
# Epoch 47/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3817 - accuracy: 0.8704 - val_loss: 0.3873 - val_accuracy: 0.8333
# Epoch 48/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3739 - accuracy: 0.8704 - val_loss: 0.3739 - val_accuracy: 0.9167
# Epoch 49/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3665 - accuracy: 0.8704 - val_loss: 0.3720 - val_accuracy: 0.8333
# Epoch 50/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3608 - accuracy: 0.8704 - val_loss: 0.3639 - val_accuracy: 0.9167
# Epoch 51/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3551 - accuracy: 0.8704 - val_loss: 0.3559 - val_accuracy: 0.9167
# Epoch 52/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8704 - val_loss: 0.3456 - val_accuracy: 0.9167
# Epoch 53/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3457 - accuracy: 0.8704 - val_loss: 0.3467 - val_accuracy: 0.9167
# Epoch 54/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3392 - accuracy: 0.8704 - val_loss: 0.3417 - val_accuracy: 0.9167
# Epoch 55/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3354 - accuracy: 0.8704 - val_loss: 0.3316 - val_accuracy: 0.9167
# Epoch 56/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3291 - accuracy: 0.8889 - val_loss: 0.3295 - val_accuracy: 0.9167
# Epoch 57/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3243 - accuracy: 0.8889 - val_loss: 0.3281 - val_accuracy: 0.9167
# Epoch 58/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3200 - accuracy: 0.8889 - val_loss: 0.3176 - val_accuracy: 0.9167
# Epoch 59/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3145 - accuracy: 0.8889 - val_loss: 0.3082 - val_accuracy: 0.9167
# Epoch 60/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3090 - accuracy: 0.8889 - val_loss: 0.3087 - val_accuracy: 0.9167
# Epoch 61/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3062 - accuracy: 0.8889 - val_loss: 0.2973 - val_accuracy: 0.9167
# Epoch 62/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3007 - accuracy: 0.8889 - val_loss: 0.2915 - val_accuracy: 0.9167
# Epoch 63/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2962 - accuracy: 0.9074 - val_loss: 0.2885 - val_accuracy: 0.9167
# Epoch 64/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2917 - accuracy: 0.9074 - val_loss: 0.2909 - val_accuracy: 0.9167
# Epoch 65/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2890 - accuracy: 0.8889 - val_loss: 0.2750 - val_accuracy: 0.9167
# Epoch 66/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2855 - accuracy: 0.9074 - val_loss: 0.2690 - val_accuracy: 0.9167
# Epoch 67/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2803 - accuracy: 0.9074 - val_loss: 0.2750 - val_accuracy: 0.9167
# Epoch 68/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2784 - accuracy: 0.9074 - val_loss: 0.2739 - val_accuracy: 0.9167
# Epoch 69/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2757 - accuracy: 0.9074 - val_loss: 0.2719 - val_accuracy: 0.9167
# Epoch 70/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2721 - accuracy: 0.9074 - val_loss: 0.2600 - val_accuracy: 0.9167
# Epoch 71/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2670 - accuracy: 0.9074 - val_loss: 0.2572 - val_accuracy: 0.9167
# Epoch 72/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2643 - accuracy: 0.9074 - val_loss: 0.2472 - val_accuracy: 0.9167
# Epoch 73/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2617 - accuracy: 0.9074 - val_loss: 0.2475 - val_accuracy: 0.9167
# Epoch 74/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2584 - accuracy: 0.9074 - val_loss: 0.2424 - val_accuracy: 0.9167
# Epoch 75/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2555 - accuracy: 0.9074 - val_loss: 0.2409 - val_accuracy: 0.9167
# Epoch 76/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2512 - accuracy: 0.9074 - val_loss: 0.2331 - val_accuracy: 0.9167
# Epoch 77/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2469 - accuracy: 0.9074 - val_loss: 0.2359 - val_accuracy: 0.9167
# Epoch 78/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2466 - accuracy: 0.9074 - val_loss: 0.2286 - val_accuracy: 0.9167
# Epoch 79/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2431 - accuracy: 0.9074 - val_loss: 0.2255 - val_accuracy: 0.9167
# Epoch 80/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2396 - accuracy: 0.9074 - val_loss: 0.2204 - val_accuracy: 0.9167
# Epoch 81/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2377 - accuracy: 0.9074 - val_loss: 0.2228 - val_accuracy: 0.9167
# Epoch 82/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2381 - accuracy: 0.9074 - val_loss: 0.2330 - val_accuracy: 0.9167
# Epoch 83/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2343 - accuracy: 0.9074 - val_loss: 0.2213 - val_accuracy: 0.9167
# Epoch 84/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2338 - accuracy: 0.9074 - val_loss: 0.2157 - val_accuracy: 0.9167
# Epoch 85/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2278 - accuracy: 0.9074 - val_loss: 0.2015 - val_accuracy: 0.9167
# Epoch 86/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2261 - accuracy: 0.9259 - val_loss: 0.1988 - val_accuracy: 0.9167
# Epoch 87/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2246 - accuracy: 0.9074 - val_loss: 0.1964 - val_accuracy: 0.9167
# Epoch 88/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2233 - accuracy: 0.9074 - val_loss: 0.2001 - val_accuracy: 0.9167
# Epoch 89/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2187 - accuracy: 0.9259 - val_loss: 0.2043 - val_accuracy: 0.9167
# Epoch 90/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2197 - accuracy: 0.9074 - val_loss: 0.2109 - val_accuracy: 0.9167
# Epoch 91/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2186 - accuracy: 0.9074 - val_loss: 0.2098 - val_accuracy: 0.9167
# Epoch 92/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2153 - accuracy: 0.9074 - val_loss: 0.1874 - val_accuracy: 0.9167
# Epoch 93/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2143 - accuracy: 0.9074 - val_loss: 0.1923 - val_accuracy: 0.9167
# Epoch 94/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2109 - accuracy: 0.9074 - val_loss: 0.1898 - val_accuracy: 0.9167
# Epoch 95/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2101 - accuracy: 0.9259 - val_loss: 0.1926 - val_accuracy: 0.9167
# Epoch 96/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2079 - accuracy: 0.9074 - val_loss: 0.1866 - val_accuracy: 0.9167
# Epoch 97/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2064 - accuracy: 0.9074 - val_loss: 0.1896 - val_accuracy: 0.9167
# Epoch 98/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2052 - accuracy: 0.9074 - val_loss: 0.1756 - val_accuracy: 0.9167
# Epoch 99/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2045 - accuracy: 0.9259 - val_loss: 0.1806 - val_accuracy: 0.9167
# Epoch 100/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2035 - accuracy: 0.9074 - val_loss: 0.1730 - val_accuracy: 0.9167

# %%
#Now lets evaluate this model on the test data
#We specify the index [1] because the evaluate function returns loss ([0]) and accuracy ([0])
model.evaluate(X_test, Y_test)[1]
# Out:
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1897 - accuracy: 0.9167
# 0.9166666865348816

# %%
#Now let's visualize the metrics we are evaluating: loss and accuracy
#We need to import matplotlib now
import matplotlib.pyplot as mat

#First we want to visualize the traing loss and the validation loss
mat.plot(hist.history['loss'])
mat.plot(hist.history['val_loss'])
mat.title('Model loss')
mat.ylabel('Loss')
mat.xlabel('Epoch')
mat.legend(['Train', 'Val'], loc='upper right')
mat.show()

#It doesn't seem like our training data is fitting our validation data very well here
#Perhaps there are some changest that can be made
#After some adjustments, I've decided to do 2 hidden layers of 16 neurons with batch_size=4 and epoch=100
#This seems to fit our data better

# %%
#Secondly we will visualize the training accuracy and the validation accuracy
mat.plot(hist.history['accuracy'])
mat.plot(hist.history['val_accuracy'])
mat.title('Model accuracy')
mat.ylabel('Accuracy')
mat.xlabel('Epoch')
mat.legend(['Train', 'Val'], loc='lower right')
mat.show()
