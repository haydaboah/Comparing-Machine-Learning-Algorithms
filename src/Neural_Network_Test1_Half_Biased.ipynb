# %%
#First we need to import the pandas library
import pandas as pd

#Load our lung cancer dataset into object ds
ds = pd.read_csv('/Users/haydenwhite/Documents/USC Upstate/599 Senior Seminar/src/survey_lung_cancer.csv')

#Lets first print the number of rows and columns of the dataset
print('Size of dataset', ds.shape)
#Lets verify our filepath is correct by previewing the data with the following head() method call
ds.head()

#If we had any cells with N/A, we can remove those rows with: ds = ds.dropna()
# Out:
# Size of dataset (309, 16)
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO

# %%
#****NOW LETS HANDLE THE BIASED DATA BY REMOVING SOME "YES"'S IN THE LUNG CANCER COLUMN*****

numNo = 0
numYes = 0
for index, row in ds.iterrows():
    if row[15] == 'NO':
            numNo += 1
    else:
        numYes += 1
print('No:', numNo)
print('Yes:', numYes)

for index, row in ds.iterrows():
    #print(row) #Debug
    if row[15] == 'YES' and numYes > numNo*2:
        ds = ds.drop(index, axis=0)
        numYes -= 1
print('No:', numNo)
print('Yes:', numYes)
ds.head()
# Out:
# No: 39
# Yes: 270
# No: 39
# Yes: 78
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2       F   59        1               1        1              2
# 3       M   63        2               2        2              1
# 4       F   63        1               2        1              1
# 8       F   68        2               1        2              1
# 12      F   60        2               1        1              1
#
#     CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 2                 1         2         1         2                  1
# 3                 1         1         1         1                  2
# 4                 1         1         1         2                  1
# 8                 1         2         1         1                  1
# 12                1         2         1         1                  1
#
#     COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 2          2                    2                      1           2
# 3          1                    1                      2           2
# 4          2                    2                      1           1
# 8          1                    1                      1           1
# 12         1                    2                      1           1
#
#    LUNG_CANCER
# 2           NO
# 3           NO
# 4           NO
# 8           NO
# 12          NO

# %%
#Now we need to make some adjustments to the data
#Lets start by replacing all the '1s' with 0 and all the '2s' with 1
#Note: 'FATIGUE ' and 'ALLERGY ' have an extra whitespace at the end of their string
ds['SMOKING'].replace({1: 0, 2: 1}, inplace = True)
ds['YELLOW_FINGERS'].replace({1: 0, 2: 1}, inplace = True)
ds['SMOKING'].replace({1: 0, 2: 1}, inplace = True)
ds['ANXIETY'].replace({1: 0, 2: 1}, inplace = True)
ds['PEER_PRESSURE'].replace({1: 0, 2: 1}, inplace = True)
ds['CHRONIC DISEASE'].replace({1: 0, 2: 1}, inplace = True)
ds['FATIGUE '].replace({1: 0, 2: 1}, inplace = True)
ds['ALLERGY '].replace({1: 0, 2: 1}, inplace = True)
ds['WHEEZING'].replace({1: 0, 2: 1}, inplace = True)
ds['ALCOHOL CONSUMING'].replace({1: 0, 2: 1}, inplace = True)
ds['COUGHING'].replace({1: 0, 2: 1}, inplace = True)
ds['SHORTNESS OF BREATH'].replace({1: 0, 2: 1}, inplace = True)
ds['SWALLOWING DIFFICULTY'].replace({1: 0, 2: 1}, inplace = True)
ds['CHEST PAIN'].replace({1: 0, 2: 1}, inplace = True)

#Now lets replace the 'YES' and 'NO' values in the 'LUNG_CANCER' column with '1' and '0' respectively
ds['LUNG_CANCER'].replace({'NO': 0, 'YES': 1}, inplace = True)

#For debugging purposes, lets replace 'M' with 1 and 'F' with 0 for the GENDER column
ds['GENDER'].replace({'F': 0, 'M': 1}, inplace = True)

ds.head()
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2        0   59        0               0        0              1
# 3        1   63        0               1        1              0
# 4        0   63        0               1        0              0
# 8        0   68        0               0        1              0
# 12       0   60        0               0        0              0
#
#     CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 2                 0         1         0         1                  0
# 3                 0         0         0         0                  1
# 4                 0         0         0         1                  0
# 8                 0         1         0         0                  0
# 12                0         1         0         0                  0
#
#     COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 2          1                    1                      0           1
# 3          0                    0                      1           1
# 4          1                    1                      0           0
# 8          0                    0                      0           0
# 12         0                    1                      0           0
#
#     LUNG_CANCER
# 2             0
# 3             0
# 4             0
# 8             0
# 12            0

# %%
#Now lets convert our dataset into an array that the machine can process
dataset = ds.values

#We can view this dataset by simply writing "dataset"
dataset
# Out:
# array([[ 0, 59,  0, ...,  0,  1,  0],
#        [ 1, 63,  0, ...,  1,  1,  0],
#        [ 0, 63,  0, ...,  0,  0,  0],
#        ...,
#        [ 1, 58,  0, ...,  0,  1,  1],
#        [ 1, 67,  0, ...,  0,  1,  1],
#        [ 1, 62,  0, ...,  1,  0,  1]])

# %%
#Now we need to split our dataset so that the input features (first 15 columns) are stored in X and 
#the output feature (column 16) is stored in Y
X = dataset[:,0:15] #Storing columns 1-15 in X
Y = dataset[:,15]   #Storing column 16 in Y

#Luckily, the vast majority  of our data is binary (either a 0 or 1) EXCEPT for the Age column
#We need to scale the age column so that it lies between 0 or 1 inclusive
#We do this by importing the processing module from sklearn
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler() #Creating the preprocessing object
X_scale = min_max_scaler.fit_transform(X)     #Scaling the input X as new variable X_scale

#Lets take a peak at how this changed the Age column
X_scale
# Out:
# array([[0.        , 0.57575758, 0.        , ..., 1.        , 0.        ,
#         1.        ],
#        [1.        , 0.63636364, 0.        , ..., 0.        , 1.        ,
#         1.        ],
#        [0.        , 0.63636364, 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [1.        , 0.56060606, 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [1.        , 0.6969697 , 0.        , ..., 1.        , 0.        ,
#         1.        ],
#        [1.        , 0.62121212, 0.        , ..., 0.        , 1.        ,
#         0.        ]])

# %%
#Now we need to split our dataset into a training set, a test set, and a validation set
#We will do so by importing test_train_spolit from sklearn.model_selection
from sklearn.model_selection import train_test_split

#We group the validation and test data into one X and Y set, and our 
#training data into another X and Y set
#test_size=0.3 means we are splitting our data such that 70% is training and 30% is test/validate
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

#Since Test data and Validation data are grouped together we can call the same function
#To split those into their own individual sets
#We will split them equally using test_size=0.5
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

#We can view the shape of all 6 arrays by printing them
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (81, 15) (18, 15) (18, 15) (81,) (18,) (18,)

# %%
#Now our data is ready to train a neural network

#Setting up the neural network, we need to decide how many hidden layers we want
#as well as how many neurons should belong to each layer

#The situations in which performance improves with a second (or third, etc.) 
#hidden layer are very few. One hidden layer is sufficient for the large majority of problems.

#So what about the size of the hidden layer(s)--how many neurons? There are some empirically derived 
#rules of thumb; of these, the most commonly relied on is 'the optimal size of the hidden layer is 
#usually between the size of the input and size of the output layers'. 

#In sum, for most problems, one could probably get decent performance (even without a second optimization step) 
#by setting the hidden layer configuration using just two rules: (i) the number of hidden layers equals one; 
#and (ii) the number of neurons in that layer is the mean of the neurons in the input and output layers. 

#With this guidence in mind, we will begin with a neural network containing one hidden layer with the amount
#of neurons equaling the mean of the input+output neurons (16) divided by 2 (16/2 = 8 layers).

#Later on we can experiment with additional hidden layers and/or neurons

#Lets import the necessary modules
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras import regularizers #Let's just test out this code for a second and see if it improves the model

#Now lets specify the architecture of the model
model = Sequential([
    Dense(16, activation='relu', input_shape=(15,)),  #Describes hidden layer and specifies number of input neurons
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid'),                  #Describes the output layer
])

#Now lets configure our model with the following attributes
#1) The algorithm for our optimization
#2) The loss function we want to use
#3) Metrics we want to track apart from the loss function

model.compile(optimizer='sgd',             #sgd refers to Stochastic Gradient Descent
              loss='binary_crossentropy',  #This means our loss function is for outputs of 0 or 1
              metrics=['accuracy'])        #We want to keep track of model accuracy for comparison

#Now we are ready to train our model
#Here we are fitting our parameters to the data
#This function outputs a history, which we store as 'hist'
hist = model.fit(X_train, Y_train,         #Specifying our training data is in X_train and Y_train
          batch_size=4, epochs=100,       #batch_size=32 and epochs=100 is a standard for NN
          validation_data=(X_val, Y_val))  #Tells us how we are doing on the validation data at each point
# Out:
# Epoch 1/100
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6403 - accuracy: 0.6296 - val_loss: 0.6500 - val_accuracy: 0.6667
# Epoch 2/100
# 21/21 [==============================] - 0s 997us/step - loss: 0.6210 - accuracy: 0.6543 - val_loss: 0.6355 - val_accuracy: 0.6111
# Epoch 3/100
# 21/21 [==============================] - 0s 963us/step - loss: 0.6057 - accuracy: 0.6543 - val_loss: 0.6252 - val_accuracy: 0.6111
# Epoch 4/100
# 21/21 [==============================] - 0s 970us/step - loss: 0.5934 - accuracy: 0.6543 - val_loss: 0.6163 - val_accuracy: 0.6111
# Epoch 5/100
# 21/21 [==============================] - 0s 944us/step - loss: 0.5830 - accuracy: 0.6543 - val_loss: 0.6091 - val_accuracy: 0.6111
# Epoch 6/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5744 - accuracy: 0.6543 - val_loss: 0.6027 - val_accuracy: 0.6111
# Epoch 7/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5664 - accuracy: 0.6543 - val_loss: 0.5965 - val_accuracy: 0.6111
# Epoch 8/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5600 - accuracy: 0.6543 - val_loss: 0.5907 - val_accuracy: 0.6111
# Epoch 9/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5539 - accuracy: 0.6543 - val_loss: 0.5845 - val_accuracy: 0.6111
# Epoch 10/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5461 - accuracy: 0.6543 - val_loss: 0.5784 - val_accuracy: 0.6111
# Epoch 11/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5401 - accuracy: 0.6543 - val_loss: 0.5730 - val_accuracy: 0.6111
# Epoch 12/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5336 - accuracy: 0.6543 - val_loss: 0.5673 - val_accuracy: 0.6667
# Epoch 13/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5278 - accuracy: 0.6543 - val_loss: 0.5617 - val_accuracy: 0.6667
# Epoch 14/100
# 21/21 [==============================] - 0s 975us/step - loss: 0.5217 - accuracy: 0.6790 - val_loss: 0.5537 - val_accuracy: 0.6667
# Epoch 15/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5158 - accuracy: 0.7160 - val_loss: 0.5471 - val_accuracy: 0.7222
# Epoch 16/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5100 - accuracy: 0.7284 - val_loss: 0.5409 - val_accuracy: 0.7222
# Epoch 17/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5031 - accuracy: 0.7407 - val_loss: 0.5345 - val_accuracy: 0.7222
# Epoch 18/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4973 - accuracy: 0.7407 - val_loss: 0.5260 - val_accuracy: 0.7222
# Epoch 19/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4892 - accuracy: 0.7654 - val_loss: 0.5181 - val_accuracy: 0.7778
# Epoch 20/100
# 21/21 [==============================] - 0s 992us/step - loss: 0.4816 - accuracy: 0.7778 - val_loss: 0.5120 - val_accuracy: 0.7778
# Epoch 21/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4747 - accuracy: 0.7778 - val_loss: 0.5039 - val_accuracy: 0.7778
# Epoch 22/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4662 - accuracy: 0.7901 - val_loss: 0.4966 - val_accuracy: 0.7778
# Epoch 23/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4575 - accuracy: 0.7901 - val_loss: 0.4880 - val_accuracy: 0.7778
# Epoch 24/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4496 - accuracy: 0.7901 - val_loss: 0.4822 - val_accuracy: 0.7778
# Epoch 25/100
# 21/21 [==============================] - 0s 937us/step - loss: 0.4424 - accuracy: 0.7901 - val_loss: 0.4760 - val_accuracy: 0.7778
# Epoch 26/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4350 - accuracy: 0.7901 - val_loss: 0.4706 - val_accuracy: 0.7778
# Epoch 27/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4270 - accuracy: 0.7901 - val_loss: 0.4640 - val_accuracy: 0.7778
# Epoch 28/100
# 21/21 [==============================] - 0s 957us/step - loss: 0.4202 - accuracy: 0.7901 - val_loss: 0.4568 - val_accuracy: 0.7778
# Epoch 29/100
# 21/21 [==============================] - 0s 981us/step - loss: 0.4130 - accuracy: 0.7901 - val_loss: 0.4511 - val_accuracy: 0.7778
# Epoch 30/100
# 21/21 [==============================] - 0s 976us/step - loss: 0.4048 - accuracy: 0.7901 - val_loss: 0.4438 - val_accuracy: 0.7778
# Epoch 31/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3978 - accuracy: 0.8025 - val_loss: 0.4381 - val_accuracy: 0.7778
# Epoch 32/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3900 - accuracy: 0.8148 - val_loss: 0.4328 - val_accuracy: 0.7778
# Epoch 33/100
# 21/21 [==============================] - 0s 1000us/step - loss: 0.3833 - accuracy: 0.8148 - val_loss: 0.4271 - val_accuracy: 0.7778
# Epoch 34/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3750 - accuracy: 0.8148 - val_loss: 0.4215 - val_accuracy: 0.7778
# Epoch 35/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3672 - accuracy: 0.8148 - val_loss: 0.4165 - val_accuracy: 0.7778
# Epoch 36/100
# 21/21 [==============================] - 0s 977us/step - loss: 0.3618 - accuracy: 0.8272 - val_loss: 0.4101 - val_accuracy: 0.7778
# Epoch 37/100
# 21/21 [==============================] - 0s 994us/step - loss: 0.3531 - accuracy: 0.8148 - val_loss: 0.4047 - val_accuracy: 0.7778
# Epoch 38/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3449 - accuracy: 0.8519 - val_loss: 0.3994 - val_accuracy: 0.7778
# Epoch 39/100
# 21/21 [==============================] - 0s 990us/step - loss: 0.3384 - accuracy: 0.8642 - val_loss: 0.3950 - val_accuracy: 0.7778
# Epoch 40/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8765 - val_loss: 0.3903 - val_accuracy: 0.7778
# Epoch 41/100
# 21/21 [==============================] - 0s 959us/step - loss: 0.3236 - accuracy: 0.8889 - val_loss: 0.3837 - val_accuracy: 0.8889
# Epoch 42/100
# 21/21 [==============================] - 0s 953us/step - loss: 0.3171 - accuracy: 0.9012 - val_loss: 0.3761 - val_accuracy: 0.8333
# Epoch 43/100
# 21/21 [==============================] - 0s 947us/step - loss: 0.3100 - accuracy: 0.9136 - val_loss: 0.3720 - val_accuracy: 0.8333
# Epoch 44/100
# 21/21 [==============================] - 0s 925us/step - loss: 0.3034 - accuracy: 0.9012 - val_loss: 0.3684 - val_accuracy: 0.8333
# Epoch 45/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2976 - accuracy: 0.9136 - val_loss: 0.3645 - val_accuracy: 0.8333
# Epoch 46/100
# 21/21 [==============================] - 0s 930us/step - loss: 0.2912 - accuracy: 0.9136 - val_loss: 0.3611 - val_accuracy: 0.8333
# Epoch 47/100
# 21/21 [==============================] - 0s 934us/step - loss: 0.2863 - accuracy: 0.9136 - val_loss: 0.3571 - val_accuracy: 0.8333
# Epoch 48/100
# 21/21 [==============================] - 0s 945us/step - loss: 0.2800 - accuracy: 0.8889 - val_loss: 0.3549 - val_accuracy: 0.8333
# Epoch 49/100
# 21/21 [==============================] - 0s 946us/step - loss: 0.2752 - accuracy: 0.9136 - val_loss: 0.3549 - val_accuracy: 0.8333
# Epoch 50/100
# 21/21 [==============================] - 0s 937us/step - loss: 0.2696 - accuracy: 0.9259 - val_loss: 0.3471 - val_accuracy: 0.8333
# Epoch 51/100
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2642 - accuracy: 0.9136 - val_loss: 0.3433 - val_accuracy: 0.8333
# Epoch 52/100
# 21/21 [==============================] - 0s 968us/step - loss: 0.2604 - accuracy: 0.9136 - val_loss: 0.3419 - val_accuracy: 0.8333
# Epoch 53/100
# 21/21 [==============================] - 0s 964us/step - loss: 0.2542 - accuracy: 0.9136 - val_loss: 0.3385 - val_accuracy: 0.8333
# Epoch 54/100
# 21/21 [==============================] - 0s 949us/step - loss: 0.2490 - accuracy: 0.9259 - val_loss: 0.3400 - val_accuracy: 0.8333
# Epoch 55/100
# 21/21 [==============================] - 0s 953us/step - loss: 0.2461 - accuracy: 0.9136 - val_loss: 0.3366 - val_accuracy: 0.8333
# Epoch 56/100
# 21/21 [==============================] - 0s 935us/step - loss: 0.2425 - accuracy: 0.9012 - val_loss: 0.3361 - val_accuracy: 0.8333
# Epoch 57/100
# 21/21 [==============================] - 0s 958us/step - loss: 0.2392 - accuracy: 0.9012 - val_loss: 0.3374 - val_accuracy: 0.8333
# Epoch 58/100
# 21/21 [==============================] - 0s 970us/step - loss: 0.2350 - accuracy: 0.9259 - val_loss: 0.3319 - val_accuracy: 0.8333
# Epoch 59/100
# 21/21 [==============================] - 0s 946us/step - loss: 0.2324 - accuracy: 0.9259 - val_loss: 0.3280 - val_accuracy: 0.8333
# Epoch 60/100
# 21/21 [==============================] - 0s 959us/step - loss: 0.2265 - accuracy: 0.9136 - val_loss: 0.3256 - val_accuracy: 0.8333
# Epoch 61/100
# 21/21 [==============================] - 0s 935us/step - loss: 0.2246 - accuracy: 0.9136 - val_loss: 0.3244 - val_accuracy: 0.8333
# Epoch 62/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2197 - accuracy: 0.9383 - val_loss: 0.3233 - val_accuracy: 0.8333
# Epoch 63/100
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2159 - accuracy: 0.9136 - val_loss: 0.3180 - val_accuracy: 0.8889
# Epoch 64/100
# 21/21 [==============================] - 0s 941us/step - loss: 0.2135 - accuracy: 0.9259 - val_loss: 0.3200 - val_accuracy: 0.8889
# Epoch 65/100
# 21/21 [==============================] - 0s 928us/step - loss: 0.2094 - accuracy: 0.9259 - val_loss: 0.3166 - val_accuracy: 0.8889
# Epoch 66/100
# 21/21 [==============================] - 0s 945us/step - loss: 0.2075 - accuracy: 0.9136 - val_loss: 0.3236 - val_accuracy: 0.8333
# Epoch 67/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2064 - accuracy: 0.9259 - val_loss: 0.3143 - val_accuracy: 0.8889
# Epoch 68/100
# 21/21 [==============================] - 0s 995us/step - loss: 0.1996 - accuracy: 0.9136 - val_loss: 0.3223 - val_accuracy: 0.8333
# Epoch 69/100
# 21/21 [==============================] - 0s 940us/step - loss: 0.1999 - accuracy: 0.9259 - val_loss: 0.3149 - val_accuracy: 0.8889
# Epoch 70/100
# 21/21 [==============================] - 0s 968us/step - loss: 0.1976 - accuracy: 0.9136 - val_loss: 0.3178 - val_accuracy: 0.8889
# Epoch 71/100
# 21/21 [==============================] - 0s 979us/step - loss: 0.1968 - accuracy: 0.9136 - val_loss: 0.3203 - val_accuracy: 0.8889
# Epoch 72/100
# 21/21 [==============================] - 0s 949us/step - loss: 0.1920 - accuracy: 0.9136 - val_loss: 0.3227 - val_accuracy: 0.8333
# Epoch 73/100
# 21/21 [==============================] - 0s 953us/step - loss: 0.1901 - accuracy: 0.9259 - val_loss: 0.3192 - val_accuracy: 0.8889
# Epoch 74/100
# 21/21 [==============================] - 0s 950us/step - loss: 0.1880 - accuracy: 0.9136 - val_loss: 0.3179 - val_accuracy: 0.8889
# Epoch 75/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1864 - accuracy: 0.9136 - val_loss: 0.3146 - val_accuracy: 0.8889
# Epoch 76/100
# 21/21 [==============================] - 0s 998us/step - loss: 0.1856 - accuracy: 0.9136 - val_loss: 0.3161 - val_accuracy: 0.8889
# Epoch 77/100
# 21/21 [==============================] - 0s 937us/step - loss: 0.1820 - accuracy: 0.9136 - val_loss: 0.3192 - val_accuracy: 0.8889
# Epoch 78/100
# 21/21 [==============================] - 0s 933us/step - loss: 0.1805 - accuracy: 0.9136 - val_loss: 0.3189 - val_accuracy: 0.8889
# Epoch 79/100
# 21/21 [==============================] - 0s 982us/step - loss: 0.1769 - accuracy: 0.9136 - val_loss: 0.3225 - val_accuracy: 0.8889
# Epoch 80/100
# 21/21 [==============================] - 0s 987us/step - loss: 0.1771 - accuracy: 0.9136 - val_loss: 0.3072 - val_accuracy: 0.8889
# Epoch 81/100
# 21/21 [==============================] - 0s 963us/step - loss: 0.1753 - accuracy: 0.9259 - val_loss: 0.3254 - val_accuracy: 0.8889
# Epoch 82/100
# 21/21 [==============================] - 0s 925us/step - loss: 0.1726 - accuracy: 0.9136 - val_loss: 0.3264 - val_accuracy: 0.8889
# Epoch 83/100
# 21/21 [==============================] - 0s 927us/step - loss: 0.1714 - accuracy: 0.9259 - val_loss: 0.3209 - val_accuracy: 0.8889
# Epoch 84/100
# 21/21 [==============================] - 0s 945us/step - loss: 0.1684 - accuracy: 0.9136 - val_loss: 0.3264 - val_accuracy: 0.8889
# Epoch 85/100
# 21/21 [==============================] - 0s 931us/step - loss: 0.1680 - accuracy: 0.9136 - val_loss: 0.3607 - val_accuracy: 0.8333
# Epoch 86/100
# 21/21 [==============================] - 0s 955us/step - loss: 0.1713 - accuracy: 0.9259 - val_loss: 0.3411 - val_accuracy: 0.8333
# Epoch 87/100
# 21/21 [==============================] - 0s 929us/step - loss: 0.1650 - accuracy: 0.9259 - val_loss: 0.3417 - val_accuracy: 0.8333
# Epoch 88/100
# 21/21 [==============================] - 0s 970us/step - loss: 0.1639 - accuracy: 0.9259 - val_loss: 0.3402 - val_accuracy: 0.8889
# Epoch 89/100
# 21/21 [==============================] - 0s 943us/step - loss: 0.1621 - accuracy: 0.9136 - val_loss: 0.3416 - val_accuracy: 0.8889
# Epoch 90/100
# 21/21 [==============================] - 0s 946us/step - loss: 0.1614 - accuracy: 0.9136 - val_loss: 0.3437 - val_accuracy: 0.8889
# Epoch 91/100
# 21/21 [==============================] - 0s 973us/step - loss: 0.1590 - accuracy: 0.9136 - val_loss: 0.3545 - val_accuracy: 0.8333
# Epoch 92/100
# 21/21 [==============================] - 0s 940us/step - loss: 0.1575 - accuracy: 0.9259 - val_loss: 0.3328 - val_accuracy: 0.8889
# Epoch 93/100
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1630 - accuracy: 0.9136 - val_loss: 0.3376 - val_accuracy: 0.8889
# Epoch 94/100
# 21/21 [==============================] - 0s 926us/step - loss: 0.1575 - accuracy: 0.9136 - val_loss: 0.3463 - val_accuracy: 0.8889
# Epoch 95/100
# 21/21 [==============================] - 0s 915us/step - loss: 0.1556 - accuracy: 0.9259 - val_loss: 0.3442 - val_accuracy: 0.8889
# Epoch 96/100
# 21/21 [==============================] - 0s 939us/step - loss: 0.1532 - accuracy: 0.9259 - val_loss: 0.3490 - val_accuracy: 0.8889
# Epoch 97/100
# 21/21 [==============================] - 0s 977us/step - loss: 0.1527 - accuracy: 0.9136 - val_loss: 0.3522 - val_accuracy: 0.8889
# Epoch 98/100
# 21/21 [==============================] - 0s 933us/step - loss: 0.1518 - accuracy: 0.9383 - val_loss: 0.3487 - val_accuracy: 0.8889
# Epoch 99/100
# 21/21 [==============================] - 0s 934us/step - loss: 0.1515 - accuracy: 0.9136 - val_loss: 0.3439 - val_accuracy: 0.8889
# Epoch 100/100
# 21/21 [==============================] - 0s 916us/step - loss: 0.1504 - accuracy: 0.9259 - val_loss: 0.3574 - val_accuracy: 0.8889

# %%
#Now lets evaluate this model on the test data
#We specify the index [1] because the evaluate function returns loss ([0]) and accuracy ([0])
model.evaluate(X_test, Y_test)[1]
# Out:
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1007 - accuracy: 1.0000
# 1.0

# %%
#Now let's visualize the metrics we are evaluating: loss and accuracy
#We need to import matplotlib now
import matplotlib.pyplot as mat

#First we want to visualize the traing loss and the validation loss
mat.plot(hist.history['loss'])
mat.plot(hist.history['val_loss'])
mat.title('Model loss')
mat.ylabel('Loss')
mat.xlabel('Epoch')
mat.legend(['Train', 'Val'], loc='upper right')
mat.show()

#It doesn't seem like our training data is fitting our validation data very well here
#Perhaps there are some changest that can be made
#After some adjustments, I've decided to do 2 hidden layers of 16 neurons with batch_size=4 and epoch=100
#This seems to fit our data better

# %%
#Secondly we will visualize the training accuracy and the validation accuracy
mat.plot(hist.history['accuracy'])
mat.plot(hist.history['val_accuracy'])
mat.title('Model accuracy')
mat.ylabel('Accuracy')
mat.xlabel('Epoch')
mat.legend(['Train', 'Val'], loc='lower right')
mat.show()
